# %% [markdown]
# # Cleaning and Formatting the Data
#
# ##### The purpose of this notebook is to read in the raw data in various formats and combine it into one master csv

# %%
import pandas as pd
import json
import os
import datetime

# %% [markdown]
# ### Part 1: Make Master DataFrame

# %% [markdown]
# First raw data was a csv called "misc_queries.csv" so let's start with that as the baseline

# %%
q = pd.read_csv('misc_queries.csv',index_col=False)

# %%
q.head()
# Out:
#                            Query    Source      Date Added  (Num Occurances)
# 0            michelle wu husband  starting  3/30/2021 0:00               NaN
# 1        andrea campbell husband  starting   4/1/2021 0:00               NaN
# 2         dana depelteau husband  starting   4/3/2021 0:00               NaN
# 3  annisa essaibi george husband  starting   4/4/2021 0:00               NaN
# 4              jon santiago wife  starting   4/6/2021 0:00               NaN

# %%
#note that the Num Occurances was a empty column that we didn't use, so let's drop that
q.drop(columns=['(Num Occurances)'],inplace=True)
q.head()
# Out:
#                            Query    Source      Date Added
# 0            michelle wu husband  starting  3/30/2021 0:00
# 1        andrea campbell husband  starting   4/1/2021 0:00
# 2         dana depelteau husband  starting   4/3/2021 0:00
# 3  annisa essaibi george husband  starting   4/4/2021 0:00
# 4              jon santiago wife  starting   4/6/2021 0:00

# %% [markdown]
# Since we want to do some analysis by city, the next thing is to make a column in the dataframe with the city that the query is from. First, we'll need the lists of candidates from each city.

# %%
cands = pd.read_csv('candidates.csv',index_col=False)
cands_bos = cands[cands.city=='Boston'].name.to_list()
cands_nyc = cands[cands.city=='New York City'].name.to_list()

# %%
cands_bos
# Out:
# ['michelle wu',
#  'andrea campbell',
#  'dana depelteau',
#  'annissa essaibi george',
#  'jon santiago',
#  'kim janey',
#  'michael bianchi',
#  'john barros']

# %%
def add_city(query):
    """looks at query and identifies which city it is part of"""
    if 'new york' in query.lower(): return 'NYC'
    elif 'boston' in query.lower(): return 'Boston'
    
    for name in cands_bos: 
        if name in query: return 'Boston'
    return 'NYC'

q['city'] = q['Query'].apply(add_city)

# %%
q[]
# Out:
#                                                     Query            Source  \
# 22                                jon santiago races 2021      autocomplete
# 23                     isaac wright jr daughter instagram      autocomplete
# 24                                       john barros wiki      autocomplete
# 25                             scott stringer backgrounds      autocomplete
# 26                  art chang mayor election results 2018      autocomplete
# ...                                                   ...               ...
# 188789                          nyc mayoral election 2021  related searches
# 188790                      nyc mayoral race 2021 results  related searches
# 188791                        nyc primary candidates 2021  related searches
# 188792                          2013 nyc mayoral election  related searches
# 188793  nyc mayoral election 2017 results by neighborhood  related searches
#
#        Date Added    city                 seed_query        candidate gender
# 22     2021-04-27  Boston          jon santiago race     jon santiago      M
# 23     2021-04-27     NYC            isaac wright jr  isaac wright jr      M
# 24     2021-04-27  Boston                john barros      john barros      M
# 25     2021-04-27     NYC  scott stringer background   scott stringer      M
# 26     2021-04-27     NYC                  art chang        art chang      M
# ...           ...     ...                        ...              ...    ...
# 188789 2021-11-09     NYC                                        None
# 188790 2021-11-09     NYC                                        None
# 188791 2021-11-09     NYC                                        None
# 188792 2021-11-09     NYC                                        None
# 188793 2021-11-09     NYC                                        None
#
# [188772 rows x 7 columns]

# %% [markdown]
# Let's also fix the date added column, because there seem to be some inconsistencies

# %%
#fix date column format
def fix_date(x):
    if x[4] == '-':
        return datetime.datetime.strptime(x,"%Y-%m-%d")
    else:
        return datetime.datetime.strptime(x[:-5],"%m/%d/%Y")
    
q['Date Added'] = q['Date Added'].apply(fix_date)
q['Date Added'].unique()
# Out:
# array(['2021-03-30T00:00:00.000000000', '2021-04-01T00:00:00.000000000',
#        '2021-04-03T00:00:00.000000000', '2021-04-04T00:00:00.000000000',
#        '2021-04-06T00:00:00.000000000', '2021-04-08T00:00:00.000000000',
#        '2021-04-10T00:00:00.000000000', '2021-04-12T00:00:00.000000000',
#        '2021-04-13T00:00:00.000000000', '2021-04-15T00:00:00.000000000',
#        '2021-04-16T00:00:00.000000000', '2021-04-18T00:00:00.000000000',
#        '2021-04-19T00:00:00.000000000', '2021-04-20T00:00:00.000000000',
#        '2021-04-21T00:00:00.000000000', '2021-04-22T00:00:00.000000000',
#        '2021-04-23T00:00:00.000000000', '2021-04-24T00:00:00.000000000',
#        '2021-04-25T00:00:00.000000000', '2021-04-26T00:00:00.000000000',
#        '2021-04-27T00:00:00.000000000', '2021-04-29T00:00:00.000000000',
#        '2021-04-30T00:00:00.000000000', '2021-05-01T00:00:00.000000000',
#        '2021-05-02T00:00:00.000000000', '2021-05-03T00:00:00.000000000',
#        '2021-05-04T00:00:00.000000000', '2021-05-05T00:00:00.000000000',
#        '2021-05-06T00:00:00.000000000', '2021-05-07T00:00:00.000000000',
#        '2021-05-08T00:00:00.000000000', '2021-05-09T00:00:00.000000000',
#        '2021-05-10T00:00:00.000000000', '2021-05-11T00:00:00.000000000',
#        '2021-05-12T00:00:00.000000000', '2021-05-13T00:00:00.000000000',
#        '2021-05-14T00:00:00.000000000', '2021-05-15T00:00:00.000000000',
#        '2021-05-16T00:00:00.000000000', '2021-05-17T00:00:00.000000000',
#        '2021-05-18T00:00:00.000000000', '2021-05-19T00:00:00.000000000',
#        '2021-05-20T00:00:00.000000000', '2021-05-21T00:00:00.000000000',
#        '2021-05-22T00:00:00.000000000', '2021-05-23T00:00:00.000000000',
#        '2021-05-24T00:00:00.000000000', '2021-05-25T00:00:00.000000000',
#        '2021-05-26T00:00:00.000000000', '2021-05-27T00:00:00.000000000',
#        '2021-05-28T00:00:00.000000000', '2021-05-29T00:00:00.000000000',
#        '2021-05-30T00:00:00.000000000', '2021-05-31T00:00:00.000000000',
#        '2021-06-01T00:00:00.000000000', '2021-06-02T00:00:00.000000000',
#        '2021-06-03T00:00:00.000000000', '2021-06-04T00:00:00.000000000',
#        '2021-06-05T00:00:00.000000000', '2021-06-06T00:00:00.000000000',
#        '2021-06-07T00:00:00.000000000', '2021-06-08T00:00:00.000000000',
#        '2021-06-09T00:00:00.000000000', '2021-06-10T00:00:00.000000000',
#        '2021-06-11T00:00:00.000000000', '2021-06-12T00:00:00.000000000',
#        '2021-06-13T00:00:00.000000000', '2021-06-14T00:00:00.000000000',
#        '2021-06-15T00:00:00.000000000', '2021-06-16T00:00:00.000000000',
#        '2021-06-17T00:00:00.000000000', '2021-06-18T00:00:00.000000000',
#        '2021-06-19T00:00:00.000000000', '2021-06-20T00:00:00.000000000'],
#       dtype='datetime64[ns]')

# %% [markdown]
# We need to combine this with the data that Emma has, which is in json format

# %%
raw = 'audit-suggestions-data'
def add_queries_to_df(city, dataframe):
    base = raw+f'/{city}/' #the city names are two separate folders 
    for f in os.listdir(raw+'/'+city):
        with open(raw+f'/{city}/'+f,encoding='utf-8') as fp:
            try:
                data = json.load(fp)
            except Exception as e:
                print(e, raw+f'/{city}/'+f)

        qdict = {} #formatting this to add to the dataframe easier
        #add the type of query
        if 'autocomplete' in f: qdict['Source'] = 'autocomplete'
        else: qdict['Source'] = 'related searches'
        #add the date in correct format
        qdict['Date Added'] = datetime.datetime.strptime(f[:f.find('_')],"%Y-%m-%d")
        qdict['city'] = city


        for seed_query in data.keys():
            #the value of the key is the list of queries stemming from that seed query
            
            if type(data[seed_query]) != list: continue
            for query in data[seed_query]:
                qdict['Query'] = query
                dataframe = dataframe.append(qdict,ignore_index=True)
    return dataframe

# %%
print(len(q))
q = add_queries_to_df("Boston",q)
print(len(q))
q = add_queries_to_df("NYC",q)
print(len(q))
# Out:
# 4133
# Expecting value: line 1 column 1 (char 0) audit-suggestions-data/Boston/2021-08-07_autocomplete.json
# Expecting value: line 1 column 1 (char 0) audit-suggestions-data/Boston/2021-11-01_related_searches.json
# 154338
# Expecting value: line 1 column 1 (char 0) audit-suggestions-data/NYC/2021-08-17_autocomplete.json
# 188794

# %%
q
# Out:
#                                                     Query            Source  \
# 22                                jon santiago races 2021      autocomplete
# 23                     isaac wright jr daughter instagram      autocomplete
# 24                                       john barros wiki      autocomplete
# 25                             scott stringer backgrounds      autocomplete
# 26                  art chang mayor election results 2018      autocomplete
# ...                                                   ...               ...
# 188789                          nyc mayoral election 2021  related searches
# 188790                      nyc mayoral race 2021 results  related searches
# 188791                        nyc primary candidates 2021  related searches
# 188792                          2013 nyc mayoral election  related searches
# 188793  nyc mayoral election 2017 results by neighborhood  related searches
#
#        Date Added    city                 seed_query        candidate gender
# 22     2021-04-27  Boston          jon santiago race     jon santiago      M
# 23     2021-04-27     NYC            isaac wright jr  isaac wright jr      M
# 24     2021-04-27  Boston                john barros      john barros      M
# 25     2021-04-27     NYC  scott stringer background   scott stringer      M
# 26     2021-04-27     NYC                  art chang        art chang      M
# ...           ...     ...                        ...              ...    ...
# 188789 2021-11-09     NYC                                        None
# 188790 2021-11-09     NYC                                        None
# 188791 2021-11-09     NYC                                        None
# 188792 2021-11-09     NYC                                        None
# 188793 2021-11-09     NYC                                        None
#
# [188772 rows x 7 columns]

# %%
#let's save this as a csv so that we don't have to run it again - it took a while!
q.to_csv('all_queries.csv',index=False)

# %% [markdown]
# ### Part 2: Add Helper Info for Analysis

# %% [markdown]
# Now that we have this baseline master csv, we want to add some information like gender, seed query stem, etc. and also separate related searches from autocomplete searches to make analysis easier

# %%
#Before starting, let's remove the seed queries from the dataframe
q = q[q.Source != 'starting']

# %% [markdown]
# ##### Subpart 2A: Find seed query that each query stemmed from
# To do this, we'll first need to generate all the seed queries. Since our seed query list was a template with [candidate] as a placeholder for the name, let's grab of lists of candidates and generate the seed queries

# %%
cands_bos_w = ['michelle wu', 'andrea campbell', 'annissa essaibi george', 'kim janey']
cands_bos_m = list(set(cands_bos) - set(cands_bos_w))
cands_nyc_w = ['maya wiley','kathryn garcia','dianne morales']
cands_nyc_m = list(set(cands_nyc) - set(cands_nyc_w))

# %%
#read in the seed queries 
s = pd.read_excel('seed_queries.xlsx', index_col=False)

# %% [markdown]
# Helper function that generates a list of queries for all candidates in a particular city

# %%
def generate_queries(city, cands):
    s = pd.read_excel('seed_queries.xlsx', sheet_name=f'{city} Seed Queries', index_col=False)
    seed_queries = s[s.Source=='seed'].Query.tolist()[2:] #exclude the 2 that are not about a specific candidate
    queries = []
    for query in seed_queries:
        queries.extend(query.replace('[candidate]',candidate) for candidate in cands)
    return queries

# %%
queries_bos = generate_queries('Boston',cands_bos)
queries_nyc = generate_queries('NYC',cands_nyc)

# %% [markdown]
# Now that we have these lists, we can go through the queries in our dataframe and add the seed query that the query resulted from

# %%
def find_seed(query, source, city):
    if source == 'autocomplete':
        if city =='Boston':
            for seed_q in list(reversed(queries_bos)): #reverse so it doesn't just get cand name first 
                if seed_q in query:
                    return seed_q
        else:
            for seed_q in list(reversed(queries_nyc)): #reverse so it doesn't just get cand name first 
                if seed_q in query:
                    return seed_q
    return ''

q['seed_query'] = q.apply(lambda x: find_seed(x['Query'], x['Source'], x['city']),axis=1)

# %%
q.seed_query.unique()
# Out:
# array(['jon santiago race', 'isaac wright jr', 'john barros',
#        'scott stringer background', 'art chang', '', 'andrew yang',
#        'curtis sliwa nyc', 'aaron foldenauer', 'curtis sliwa',
#        'eric adams', 'art chang mayoral election', 'ray mcguire',
#        'dianne morales', 'kathryn garcia', 'michelle wu for mayor',
#        'shaun donovan', 'andrew yang net worth',
#        'dana depelteau mayoral election', 'andrea campbell',
#        'paperboy prince endorsement', 'andrea campbell race',
#        'dana depelteau', 'andrew yang for mayor', 'kim janey boston',
#        'michelle wu boston', 'john barros boston',
#        'andrea campbell boston', 'art chang race',
#        'andrew yang background', 'michael bianchi', 'scott stringer',
#        'art chang endorsement', 'dianne morales net worth',
#        'art chang partner', 'ray mcguire partner', 'kim janey',
#        'scott stringer race', 'scott stringer for mayor', 'jon santiago',
#        'michelle wu', 'andrew yang nyc', 'john barros race', 'maya wiley',
#        'dana depelteau endorsement', 'curtis sliwa for mayor',
#        'scott stringer partner', 'andrea campbell mayoral election',
#        'john barros partner', 'dianne morales mayoral election',
#        'fernando mateo', 'paperboy prince', 'ray mcguire nyc',
#        'john barros for mayor', 'jon santiago mayoral election',
#        'shaun donovan mayoral election', 'fernando mateo net worth',
#        'isaac wright jr net worth', 'fernando mateo transportation',
#        'kathryn garcia mayoral election', 'jon santiago boston',
#        'dana depelteau partner', 'annissa essaibi george boston',
#        'aaron foldenauer mayoral election', 'jon santiago endorsement',
#        'kathryn garcia nyc', 'andrew yang endorsement',
#        'ray mcguire for mayor', 'kathryn garcia net worth',
#        'dana depelteau net worth', 'dianne morales for mayor',
#        'eric adams for mayor', 'curtis sliwa race', 'eric adams nyc',
#        'maya wiley for mayor', 'maya wiley mayoral election',
#        'dana depelteau background', 'michael bianchi endorsement',
#        'andrea campbell endorsement', 'dianne morales endorsement',
#        'curtis sliwa mayoral election', 'jon santiago partner',
#        'maya wiley endorsement', 'fernando mateo endorsement',
#        'andrea campbell net worth', 'paperboy prince net worth',
#        'michelle wu mayoral election', 'john barros endorsement',
#        'fernando mateo mayoral election', 'michelle wu endorsement',
#        'curtis sliwa net worth', 'scott stringer endorsement',
#        'shaun donovan nyc', 'scott stringer nyc',
#        'john barros mayoral election', 'dianne morales partner',
#        'michelle wu partner', 'maya wiley partner',
#        'fernando mateo partner', 'kim janey endorsement',
#        'andrea campbell for mayor', 'shaun donovan endorsement',
#        'dianne morales nyc', 'andrew yang transportation',
#        'fernando mateo race', 'shaun donovan partner',
#        'aaron foldenauer race', 'paperboy prince transportation',
#        'kathryn garcia endorsement', 'eric adams endorsement',
#        'john barros transportation', 'ray mcguire endorsement',
#        'scott stringer transportation', 'aaron foldenauer nyc',
#        'curtis sliwa endorsement', 'michelle wu race',
#        'michael bianchi boston', 'aaron foldenauer net worth',
#        'curtis sliwa transportation', 'andrea campbell transportation',
#        'andrea campbell partner', 'kim janey mayoral election',
#        'dana depelteau transportation', 'aaron foldenauer partner',
#        'shaun donovan for mayor', 'isaac wright jr nyc',
#        'jon santiago net worth', 'michael bianchi mayoral election',
#        'paperboy prince nyc', 'kathryn garcia partner',
#        'kathryn garcia for mayor', 'kim janey for mayor',
#        'paperboy prince mayoral election', 'fernando mateo for mayor',
#        'art chang nyc', 'dana depelteau boston', 'maya wiley nyc',
#        'paperboy prince background', 'jon santiago background',
#        'aaron foldenauer endorsement', 'michael bianchi partner',
#        'michael bianchi background', 'michael bianchi for mayor',
#        'michelle wu background', 'michael bianchi transportation',
#        'eric adams partner', 'dana depelteau race',
#        'eric adams background', 'michael bianchi race',
#        'paperboy prince race', 'andrew yang race', 'ray mcguire race',
#        'john barros net worth', 'aaron foldenauer transportation',
#        'kim janey race', 'michael bianchi net worth',
#        'dianne morales race', 'john barros background', 'eric adams race',
#        'kim janey partner', 'annissa essaibi george',
#        'aaron foldenauer background', 'fernando mateo background',
#        'jon santiago transportation', 'shaun donovan background',
#        'dianne morales transportation', 'ray mcguire mayoral election',
#        'kathryn garcia race', 'art chang for mayor',
#        'maya wiley transportation', 'andrea campbell background',
#        'art chang background', 'kim janey background',
#        'shaun donovan race', 'art chang net worth',
#        'andrew yang mayoral election', 'maya wiley background',
#        'dianne morales background', 'dana depelteau for mayor',
#        'ray mcguire transportation', 'kathryn garcia background',
#        'paperboy prince for mayor', 'maya wiley race',
#        'shaun donovan transportation', 'eric adams net worth',
#        'curtis sliwa partner', 'kathryn garcia transportation',
#        'kim janey transportation', 'curtis sliwa background',
#        'eric adams transportation', 'maya wiley net worth',
#        'kim janey net worth', 'michelle wu net worth',
#        'andrew yang partner', 'shaun donovan net worth',
#        'scott stringer mayoral election', 'aaron foldenauer for mayor',
#        'ray mcguire background', 'fernando mateo nyc',
#        'eric adams mayoral election', 'ray mcguire net worth',
#        'michelle wu transportation', 'art chang transportation',
#        'jon santiago for mayor', 'michelle wu COVID',
#        'andrea campbell COVID', 'dana depelteau COVID',
#        'jon santiago COVID', 'kim janey COVID', 'michael bianchi COVID',
#        'john barros COVID', 'michelle wu MBTA', 'andrea campbell MBTA',
#        'dana depelteau MBTA', 'jon santiago MBTA', 'kim janey MBTA',
#        'michael bianchi MBTA', 'john barros MBTA',
#        'michelle wu Education', 'andrea campbell Education',
#        'dana depelteau Education', 'jon santiago Education',
#        'kim janey Education', 'michael bianchi Education',
#        'john barros Education', 'michelle wu LGBT',
#        'andrea campbell LGBT', 'dana depelteau LGBT', 'jon santiago LGBT',
#        'kim janey LGBT', 'michael bianchi LGBT', 'john barros LGBT',
#        'eric adams MTA', 'eric adams LGBT', 'curtis sliwa MTA',
#        'curtis sliwa LGBT'], dtype=object)

# %%
q.head()
# Out:
#                                     Query        Source Date Added    city  \
# 22                jon santiago races 2021  autocomplete 2021-04-27  Boston
# 23     isaac wright jr daughter instagram  autocomplete 2021-04-27     NYC
# 24                       john barros wiki  autocomplete 2021-04-27  Boston
# 25             scott stringer backgrounds  autocomplete 2021-04-27     NYC
# 26  art chang mayor election results 2018  autocomplete 2021-04-27     NYC
#
#                    seed_query        candidate gender
# 22          jon santiago race     jon santiago      M
# 23            isaac wright jr  isaac wright jr      M
# 24                john barros      john barros      M
# 25  scott stringer background   scott stringer      M
# 26                  art chang        art chang      M

# %% [markdown]
# ##### Subpart 2B: Add the name of the candidate that the query is about as well as the gender of that candidate

# %%
def add_cand(query, city):
    if city =='Boston':
        for candidate in cands_bos:
            if candidate in query: return candidate
    else:
        for candidate in cands_nyc:
            if candidate in query: return candidate      

def get_gender(candidate, city):
    if city =='Boston':
        if candidate in cands_bos_w: return 'W'
        elif str(candidate) == 'None': return ''
        else: return 'M'
    else:
        if candidate in cands_nyc_w: return 'W'
        elif str(candidate) == 'None': return ''
        else: return 'M'

q['candidate'] = q.apply(lambda x: add_cand(x['Query'], x['city']),axis=1)
q['gender'] = q.apply(lambda x: get_gender(x['candidate'], x['city']),axis=1)

# %%
q[(q.candidate.isnull())&(q.Query.str.contains('george'))].Query.unique()
# Out:
# array(['annissa essaibi george bio', 'annissa essaibi george race 2020',
#        'annissa essaibi george lgbt', 'annissa essaibi george',
#        'annissa essaibi george mayoral election 2021',
#        'annissa essaibi george mayoral election 2019 candidates',
#        'annissa essaibi george net worth 2018',
#        'annissa essaibi george husband',
#        'annissa essaibi george mayoral election 2018',
#        'annissa essaibi george instagram',
#        'annissa essaibi george education',
#        'annissa essaibi george campaign manager',
#        'annissa essaibi george for mayor', 'annissa essaibi george mayor',
#        'annissa essaibi george family',
#        'annissa essaibi george race 2021',
#        'annissa essaibi george net worth forbes',
#        'annissa essaibi george endorsements',
#        'annissa essaibi george mayoral election 2018 candidates',
#        'annissa essaibi george mayoral elections 2021',
#        'annissa essaibi george twitter',
#        'annissa essaibi george mayoral elections',
#        'annissa essaibi george mayoral elections 2018',
#        'annissa essaibi george mayoral election 2019',
#        'annissa essaibi george business',
#        'annissa essaibi george net worth forbes 2018',
#        'annissa essaibi george mayoral election',
#        'annissa essaibi george facebook',
#        'annissa essaibi george mayoral election 2018 polls',
#        'annissa essaibi george mayoral elections chicago',
#        'annissa essaibi george mbta', 'annissa essaibi george net worth',
#        'annissa essaibi george partners',
#        'annissa essaibi george campaign website', 'doug george boston',
#        'annissa essaibi george website', 'doug george',
#        'annissa essaibi george father', 'annissa essaibi george covid',
#        'annissa essaibi george background', 'annissa essaibi george race',
#        'george wiley', 'annissa essaibi george wiki',
#        'doug george dorchester', 'annissa essaibi george campaign',
#        'annissa essaibi george partner',
#        'annissa essaibi george transportation',
#        'annissa essaibi george fundraising',
#        'annissa essaibi george donate', 'annissa essaibi-george masks',
#        'annissa essaibi george jobs',
#        'annissa essaibi george partnership',
#        'committee to elect annissa essaibi george',
#        'annissa essaibi george endorsement',
#        'annissa essaibi george ethnicity', 'annissa essaibi george age',
#        'annissa george', 'annissa essaibi george mayor election results',
#        'annissa essaibi george mayor election 2018',
#        'annissa essaibi george mayoral election 2020',
#        'annissa essaibi george mayor election',
#        'annissa essaibi george mayor election results 2020',
#        'annissa essaibi george mayor election results 2018',
#        'annissa essaibi george mayor election 2020',
#        'annissa essaibi george pronunciation',
#        'how much money is prince george worth',
#        'how much is prince george worth', 'annissa essaibi george staff',
#        'annissa essaibi george woman of color',
#        'annissa essaibi george parents',
#        'annissa essaibi george rent control',
#        'annissa essaibi george mayoral election results',
#        'annissa essaibi george mayoral election results 2020',
#        'annissa essaibi george mayoral election results 2021',
#        'annissa essaibi george mayor elections',
#        'annissa essaibi george mayor elections 2018',
#        'annissa essaibi george mayor elections chicago',
#        'annissa essaibi george mayor election 2021',
#        'annissa essaibi george poll', 'annissa essaibi george COVID',
#        'annissa essaibi george MBTA', 'annissa essaibi george Education',
#        'annissa essaibi george LGBT', 'annissa essaibi george lgbtq',
#        'annissa essaibi george crime',
#        'annissa essaibi george crime scene photos',
#        'annissa essaibi george crime and punishment',
#        'annissa essaibi george crimes',
#        'annissa essaibi george crime junkie',
#        'annissa essaibi george crime and punishment sparknotes',
#        'annissa essaibi george crime junkies',
#        'annissa essaibi george crime junkie podcast',
#        'annissa essaibi george crime junkie website',
#        'annissa essaibi george police', 'annissa essaibi george housing',
#        'annissa essaibi-george police',
#        'annissa essaibi-george weight loss',
#        'annissa essaibi-george instagram',
#        'annissa essaibi george covid vaccine',
#        'annissa essaibi george campaign office',
#        'annissa essaibi george crime and punishment summary',
#        'annissa essaibi george weight loss',
#        'annissa essaibi george transportation company',
#        'annissa essaibi george crime and punishment pdf',
#        'annissa essaibi george crime scene',
#        'annissa essaibi george crime scene investigator',
#        'annissa essaibi george mayor election 2018 results',
#        'annissa essaibi george covid vaccines',
#        'annissa essaibi george lgbtq+',
#        'annissa essaibi george mayor polls',
#        'annissa essaibi george mayor plan',
#        'annissa essaibi george covid-19',
#        'annissa essaibi george covid-19 vaccine',
#        'city councilor annissa essaibi-george',
#        'annissa essaibi george political views', 'douglas george boston',
#        'annissa essaibi george person of color',
#        'annissa essaibi george mother',
#        'annissa essaibi george commercial',
#        'annissa essaibi george nationality',
#        'where does annissa essaibi george live',
#        'annissa essaibi george dorchester ma',
#        'annissa essaibi george running for mayor',
#        'annissa essaibi george taxes', 'annissa essaibi george polls',
#        'george for boston mayor', 'doug george developer',
#        'annissa essaibi george siblings',
#        'annissa essaibi george mass and cass',
#        'boston mayoral candidates george',
#        'is annissa essaibi george black',
#        'annissa essaibi george religion', 'annissa essaibi george house',
#        'is annissa essaibi george white',
#        'annissa essaibi george political party',
#        'essaibi george ethnicity', 'annissa essaibi george tiktok',
#        'ethnicity annissa essaibi george', 'essaibi george husband',
#        'is annissa essaibi george a republican',
#        'annissa essaibi george campaign ad',
#        'annissa essaibi george profile',
#        'annissa essaibi george triplets',
#        'annissa essaibi george development',
#        'annissa essaibi george lebanese', 'annissa essaibi george white',
#        'annissa essaibi george new balance',
#        'annissa essaibi george trump',
#        'boston mayoral candidates essaibi george',
#        'annissa essaibi george education plan',
#        'annissa essaibi george ethnic background',
#        'annissa essaibi george accent', 'annissa essaibi george ad',
#        'annissa essaibi george sons', 'boston mayoral candidate george'],
#       dtype=object)

# %%
q[q.gender=='W'].candidate.unique()
# Out:
# array(['dianne morales', 'kathryn garcia', 'michelle wu',
#        'andrea campbell', 'kim janey', 'maya wiley',
#        'annissa essaibi george'], dtype=object)

# %%
q[q.gender=='M'].candidate.unique()
# Out:
# array(['jon santiago', 'isaac wright jr', 'john barros', 'scott stringer',
#        'art chang', 'andrew yang', 'curtis sliwa', 'aaron foldenauer',
#        'eric adams', 'ray mcguire', 'shaun donovan', 'dana depelteau',
#        'paperboy prince', 'michael bianchi', 'fernando mateo'],
#       dtype=object)

# %%
q = q.replace('annisa','annissa',regex=True)

# %% [markdown]
# Now let's save this dataframe for future use!

# %%
q.to_csv('all_queries_with_data.csv',index=False)

# %% [markdown]
# ### Part 3: Create Dataframes of just Related and Autocomplete Searches

# %%
q = pd.read_csv('all_queries_with_data.csv',index_col=False)

# %%
q[q.Source=='related searches'].to_csv('all_queries_related.csv',index=False)

# %%
q[q.Source=='autocomplete'].to_csv('all_queries_autocomplete.csv',index=False)
